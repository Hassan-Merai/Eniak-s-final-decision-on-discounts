# %% [markdown]
# # Quality Assessment
# Now it's your turn. Follow the steps on the platform and use what you've learnt to see how reliable the data is.

# %%
import pandas as pd

# %% [markdown]
# Load our cleaned DataFrames

# %%
# orders_cl.csv
url = "https://drive.google.com/file/d/1Tla62vfu__kCqvgypZyVt2S9VuC016yH/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orders_cl = pd.read_csv(path)

# orderlines_cl.csv
url = "https://drive.google.com/file/d/1OhtkQS2fwOYdzfd-qPh7im35iLc-L9TA/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orderlines_cl = pd.read_csv(path)

# products_cl.csv
url = "https://drive.google.com/file/d/1s7Lai4NSlsYjGEPg1QSOUJobNYVsZBOJ/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products_cl = pd.read_csv(path)

# %% [markdown]
# ## 1.&nbsp; Define Pandas display format

# %%
# your code here
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_rows', 1000)

# %%
pr_df=products_cl.copy()
ol_df=orderlines_cl.copy()
or_df=orders_cl.copy()

# %%
or_df.groupby('state').count()
# Out:
#                  order_id  created_date  total_paid
# state
# Cancelled            7233          7233        7233
# Completed           46605         46605       46605
# Pending             14374         14374       14374
# Place Order         40883         40883       40883
# Shopping Basket    117809        117809      117809

# %% [markdown]
# ## 2.&nbsp; Exclude unwanted orders

# %%
# your code here
or_df=or_df.loc[or_df['state'].isin(['Completed']), :]

# %%
or_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41737 entries, 0 to 78085
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          41737 non-null  int64
#  1   created_date      41737 non-null  datetime64[ns]
#  2   total_paid        41737 non-null  float64
#  3   state             41737 non-null  object
#  4   unit_price_total  41737 non-null  float64
#  5   diff              41737 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
or_df['created_date']=pd.to_datetime(or_df['created_date'])

# %%
or_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41737 entries, 0 to 78085
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          41737 non-null  int64
#  1   created_date      41737 non-null  datetime64[ns]
#  2   total_paid        41737 non-null  float64
#  3   state             41737 non-null  object
#  4   unit_price_total  41737 non-null  float64
#  5   diff              41737 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
ol_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98664 entries, 0 to 98663
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     98664 non-null  int64
#  1   id_order               98664 non-null  int64
#  2   product_id             98664 non-null  int64
#  3   product_quantity       98664 non-null  int64
#  4   sku                    98664 non-null  object
#  5   unit_price             98664 non-null  float64
#  6   date                   98664 non-null  object
#  7   unit_price_total       98664 non-null  float64
#  8   name                   98664 non-null  object
#  9   desc                   98664 non-null  object
#  10  price                  98664 non-null  float64
#  11  in_stock               98664 non-null  int64
#  12  type                   98611 non-null  object
#  13  discount               98664 non-null  float64
# ...

# %%
ol_df
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 3      1119133    299555           0                 1    BEA0065      256.49
# 4      1119134    299556           0                 1  CRU0039-A       60.90
# ...        ...       ...         ...               ...        ...         ...
# 98659  1650193    527394           0                 1    APP1922      161.00
# 98660  1650195    527396           0                 1    PAC0653      141.58
# 98661  1650196    527384           0                 1    LAC0227      249.99
# 98662  1650198    527397           0                 1    JBL0122       42.99
# 98663  1650203    527401           0                 1    APP0927       13.99
#
# ...

# %%
pr_df.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                 desc  price  in_stock  \
# 0       Aluminum support compatible with all MacBook  59.99         1
# 1          USB ultrathin keyboard Apple Mac Spanish.  59.00         0
# 2                             mouse Apple USB cable.  59.00         0
# 3              IPhone dock and USB Cable Apple iPod.  25.00         0
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99         1
#
#        type
# 0      8696
# 1  13855401
# 2      1387
# 3      1230
# 4      1364

# %% [markdown]
# ## 3.&nbsp; Exclude orders with unknown products

# %%
ol_df =ol_df.loc[ol_df['sku'].isin(pr_df['sku']),:]

# %%
# your code here
#ol_df=ol_df.drop('product_id', axis=1)

# %%
or_df=or_df.loc[or_df['order_id'].isin(ol_df['id_order']), :]

# %%
ol_df= ol_df.loc[ol_df['id_order'].isin(or_df['order_id']),:]

# %% [markdown]
# ## 4.&nbsp; Explore the revenue from different tables

# %% [markdown]
# #### Step 1:
# Create the `unit_price_total` as `orderlines.unit_price` * `orderlines.product_quantity`

# %%
# your code here
ol_df['unit_price_total'] = ol_df['unit_price'] * ol_df['product_quantity']

# %% [markdown]
# #### Step 2:
# Group by `id_order`, summarising by the sum of `unit_price_total`

# %%
# your code here
upt_df=ol_df.groupby('id_order')['unit_price_total'].sum()

# %%
upt_df
# Out:
# id_order
# 241423   129.16
# 242832    10.77
# 243330    77.99
# 245275   149.00
# 245595   105.98
#           ...
# 527042    13.99
# 527070    19.98
# 527074    19.98
# 527096    29.97
# 527112     9.99
# Name: unit_price_total, Length: 41737, dtype: float64

# %%
upt_df=upt_df.reset_index()

# %%
upt_df.head()
# Out:
#    id_order  unit_price_total
# 0    241423            129.16
# 1    242832             10.77
# 2    243330             77.99
# 3    245275            149.00
# 4    245595            105.98

# %%
#upt_df['id_order'] = upt_df['id_order'].rename('order_id', inplace=True)
upt_df.rename(columns={'id_order': 'order_id'}, inplace=True)

# %%
upt_df.head()
# Out:
#    order_id  unit_price_total
# 0    241423            129.16
# 1    242832             10.77
# 2    243330             77.99
# 3    245275            149.00
# 4    245595            105.98

# %%
or_df.head()
# Out:
#    order_id        created_date  total_paid      state  unit_price_total  diff
# 0    241423 2017-11-06 13:10:02      136.15  Completed            129.16  6.99
# 1    242832 2017-12-31 17:40:03       15.76  Completed             10.77  4.99
# 2    243330 2017-02-16 10:59:38       84.98  Completed             77.99  6.99
# 3    245275 2017-06-28 11:35:37      149.00  Completed            149.00  0.00
# 4    245595 2017-01-21 12:52:47      112.97  Completed            105.98  6.99

# %%
or_df=or_df.merge(upt_df, on ='order_id' , how='inner')

# %%
or_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41737 entries, 0 to 41736
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            41737 non-null  int64
#  1   created_date        41737 non-null  datetime64[ns]
#  2   total_paid          41737 non-null  float64
#  3   state               41737 non-null  object
#  4   unit_price_total_x  41737 non-null  float64
#  5   diff                41737 non-null  float64
#  6   unit_price_total_y  41737 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 2.2+ MB

# %% [markdown]
# ### What is the average difference between `total_paid` and `unit_price_total`?

# %%
# your code here
or_df['diff'] = or_df['total_paid'] - or_df['unit_price_total']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'unit_price_total'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-202-96564faa0ef1> in <cell line: 0>()
#       1 # your code here
# ...

# %%
m=or_df['diff'].abs().mean().round(2)
m
# Out:
# 4.25

# %% [markdown]
# ### What is the distribution of these differences?

# %%
# your code here
or_df['diff'].describe()
# Out:
# count   41737.00
# mean        4.16
# std         3.72
# min      -165.00
# 25%         0.00
# 50%         4.99
# 75%         6.99
# max        20.00
# Name: diff, dtype: float64

# %%
quantiles = or_df['diff'].quantile([0.1, 0.25, 0.5, 0.75, 0.9])
print(quantiles)
# Out:
# 0.10   0.00
# 0.25   0.00
# 0.50   4.99
# 0.75   6.99
# 0.90   6.99
# Name: diff, dtype: float64

# %%
or_df['diff'].count()
# Out:
# 41737

# %%
(or_df['diff']>10).sum()
# Out:
# 824

# %% [markdown]
# ### Can all the differences be explained by shipping costs? If not, what are other plausible explanations?

# %% [markdown]
# I think most of the difirences are supposed to be shipping costs unless the outliers. So I will remove all orders that contain any diffirence more than 20 Euro.

# %%
# your explanation here
or_df=or_df.loc[or_df['diff']<20,:]

# %% [markdown]
# ### If there are differences that you can’t explain: what should you do with these orders?

# %% [markdown]
# ## 5.&nbsp; Become confident about your dataset

# %% [markdown]
# Let's hear your thoughts about what you discovered.

# %%
# your thoughts & code her
ol_df=ol_df.merge(pr_df, on= 'sku', how='inner')

# %%
ol_df['discount']=ol_df['price'] -ol_df['unit_price']

# %%
ol_df['discount_percentage_%']=ol_df['discount']*100 / ol_df['price']

# %%
ol_df.head()
# Out:
#         id  id_order  product_id  product_quantity        sku  unit_price  \
# 0  1119116    299545           0                 1    OWC0100       47.49
# 1  1119119    299546           0                 1    IOT0014       18.99
# 2  1119120    295347           0                 1    APP0700       72.19
# 3  1119133    299555           0                 1    BEA0065      256.49
# 4  1119134    299556           0                 1  CRU0039-A       60.90
#
#                   date  unit_price_total  \
# 0  2017-01-01 01:46:16             47.49
# 1  2017-01-01 01:50:34             18.99
# 2  2017-01-01 01:54:11             72.19
# 3  2017-01-01 02:18:45            256.49
# 4  2017-01-01 02:20:14             60.90
#
#                                                 name  \
# 0  OWC In-line Digital Temperature Sensor Kit HDD...
# 1               iOttie Easy View 2 Car Black Support
# 2  Apple 85W MagSafe 2 charger MacBook Pro screen...
# ...

# %% [markdown]
# Do not forget to download your quality controlled DataFrames

# %%
from google.colab import files

or_df.to_csv("orders_qu.csv", index=False)
files.download("orders_qu.csv")

ol_df.to_csv("orderlines_qu.csv", index=False)
files.download("orderlines_qu.csv")
